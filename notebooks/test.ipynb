# %%
import requests
import numpy as np
import matplotlib.pyplot as plt

# %%
headers = {
  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjk2ODU2NDMzLCJpYXQiOjE2OTY3NzAwMzMsImp0aSI6IjUxMmEyNWE1YjAxMTRkN2ZhNGI0MjA0ZDA5YTk0MTQ3IiwidXNlcl9pZCI6MTF9.SHjoiild-XRGEeFDvDo0vQV8Ii6OUevpX7zhFu1ZEM0'
}

# %%
# How to make a get request to retrieve all of a user's videos
all_videos = requests.get("http://127.0.0.1:8000/api/video/", headers={
  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjk2ODU2NDMzLCJpYXQiOjE2OTY3NzAwMzMsImp0aSI6IjUxMmEyNWE1YjAxMTRkN2ZhNGI0MjA0ZDA5YTk0MTQ3IiwidXNlcl9pZCI6MTF9.SHjoiild-XRGEeFDvDo0vQV8Ii6OUevpX7zhFu1ZEM0'
})

# %%
all_videos.json()[0]
# Out:
# {'id': 20,
#  'owner': 'forgamesonly057@gmail.com',
#  'owner_id': 13,
#  'title': 'sample-5s',
#  'path': 'http://127.0.0.1:8000/media/videos/sample-5s_g6BscaH.mp4',
#  'pose_path': None,
#  'tags': 'ysg',
#  'created': '2023-08-30T17:35:28.742581Z',
#  'is_pose_processing': False}

# %%
pose_51 = requests.get("http://127.0.0.1:8000/api/pose/get/51/", headers=headers)

# %%
pose_51.json()
# Out:
# {'owner': 'tristanpank@gmail.com',
#  'owner_id': 11,
#  'video': 51,
# ...

# %%
def convert_str_to_numpy(data: str):
  frames = data.split(";")
  pose_array = np.zeros([len(frames), 33], dtype=float)
  for i in range(len(frames) - 1):
    frame = np.fromstring(frames[i], dtype=float, sep=",")
    pose_array[i, :] = frame
  return pose_array

# %%
# Using python for loops seems to be faster in this scenario
def convert_str_to_numpy2(data: str):
  frames = data.split(";")
  pose_array = []
  for i in range(len(frames) - 1):
    frame = [float(num) for num in frames[i].split(',')]
    pose_array.append(frame)
  return np.array(pose_array)

# %%
# %%timeit
pose_array = convert_str_to_numpy(pose_51.json()["x_values"])
# Out:
# 2.62 ms ± 49.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
pose_array2 = convert_str_to_numpy2(pose_51.json()["x_values"])
# Out:
# 2.44 ms ± 46.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Out:
# array([[0.37139636, 0.37934539, 0.38817674, ..., 0.21533105, 0.69179177,
#         0.16592702],
#        [0.36489695, 0.3738251 , 0.38251305, ..., 0.2165176 , 0.68288589,
#         0.17528816],
#        [0.35722676, 0.36583593, 0.37410438, ..., 0.2134082 , 0.68265384,
#         0.17178296],
#        ...,
#        [0.78675342, 0.80216402, 0.81188649, ..., 0.31431094, 0.72528195,
#         0.22845218],
#        [0.79456609, 0.81115156, 0.82239753, ..., 0.29930344, 0.71839029,
#         0.20245051],
#        [0.80681092, 0.8256194 , 0.83573687, ..., 0.27274728, 0.7185365 ,
#         0.13207933]])
